# %% [markdown]
# <a href="https://colab.research.google.com/github/Hatsuhinode/Python/blob/main/basicPython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Types in Python**

# %% [markdown]
# ### Numeric Type Data

# %%
integerData = 10
floatingPointNumber = 10.5
complexNumber = 10 + 8j

# %%
complexNumber.real
# Out:
# 10.0

# %%
complexNumber.imag
# Out:
# 8.0

# %%
type(integerData)
# Out:
# int

# %%
type(floatingPointNumber)
# Out:
# float

# %%
type(complexNumber)
# Out:
# complex

# %%
integerData + complexNumber
# Out:
# (20+8j)

# %%
floatingPointNumber + complexNumber
# Out:
# (20.5+8j)

# %%
integerData / complexNumber
# Out:
# (0.6097560975609757-0.48780487804878053j)

# %%
floatingPointNumber / complexNumber
# Out:
# (0.6402439024390244-0.5121951219512195j)

# %% [markdown]
# #### Multiplication , Power and Subtraction operations are also possible between all 3 numeric data types.

# %%
integer1 = int(floatingPointNumber)
integer1
# Out:
# 10

# %%
floating1 = float(integerData)
floating1
# Out:
# 10.0

# %%
integerReal = int(complexNumber.real)
integerReal
# Out:
# 10

# %%
type(complexNumber.real)
# Out:
# float

# %%
print(complexNumber.real)
# Out:
# 10.0

# %%
type(complexNumber.imag)
# Out:
# float

# %%
print(complexNumber.imag)
# Out:
# 8.0

# %% [markdown]
# ### Sequence type data

# %%
stringData = 'Doraemon'
type(stringData)
# Out:
# str

# %%
int(stringData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-188426afc78f> in <cell line: 1>()
# ----> 1 int(stringData)
#
# ValueError: invalid literal for int() with base 10: 'Doraemon'

# %%
stringData2 = '323'
int(stringData2)
# Out:
# 323

# %%
float(stringData2)
# Out:
# 323.0

# %%
complex1 = complex(integerData)
complex1
# Out:
# (10+0j)

# %%
complex2 = complex(floatingPointNumber)
complex2
# Out:
# (10.5+0j)

# %% [markdown]
# #### List and Tuples are also sequence type datas.

# %% [markdown]
# ### Mapping Type Data

# %% [markdown]
# #### Dictionary is mapping type data.

# %% [markdown]
# ### Set Type Data

# %% [markdown]
# #### Sets are set type datas.

# %% [markdown]
# ### Boolean Type Data

# %%
booleanData = True
type (booleanData)
# Out:
# bool

# %%
not booleanData
# Out:
# False

# %% [markdown]
# ### None type data

# %%
noneData = None # None type data is used to denote no value.
type(None)
# Out:
# NoneType

# %% [markdown]
# #### Input from user

# %%
num1 = input("Enter first number:\n")
num2 = input("Enter second number:\n")

# %% [markdown]
# # Mathematical operations in Python

# %% [markdown]
# ### Addition operation

# %%
print(num1 + num2)
# Out:
# 1213

# %%
n1 = int(num1)
n2 = int(num2)

# %%
n1 + n2
# Out:
# 25

# %%
num1 + num2
# Out:
# '1213'

# %% [markdown]
# <pre> 1. For addition                 n1+n2 </pre>
# <pre> 2. For multiplication           n1 * n2 </pre>
# <pre> 3. For subtraction              n1 - n2 </pre>
# <pre> 4. For exponentiation           n1 ** n2 </pre>
# <pre> 5. For division                 n1 / n2 </pre>
# <pre> 6. For floor division           n1//n2 </pre>
# <pre> 7. For modulus                  n1 % n2 </pre>

# %% [markdown]
# ### Multiplication operation

# %%
n1 * n2
# Out:
# 200

# %% [markdown]
# ###Power

# %%
2 ** 3
# Out:
# 8

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# ### Subtraction operation

# %%
n1 - n2
# Out:
# -10

# %% [markdown]
# ### Division operation

# %%
99 / 5
# Out:
# 19.8

# %%
int(99 / 5)
# Out:
# 19

# %%
10/3
# Out:
# 3.3333333333333335

# %%
int(10 / 3)
# Out:
# 3

# %%
# 10\3
# Out:
# 103

# %% [markdown]
# ### Importing Library

# %%
import math

# %%
ceilingResult = math.ceil(99/5)
print(ceilingResult)
# Out:
# 20

# %%
floorResult = math.floor(99/5)
floorResult
# Out:
# 19

# %%
99//5
# Out:
# 19

# %% [markdown]
# ### Modulus operation

# %%
10 % 3
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %% [markdown]
# # Precedence of operators

# %% [markdown]
# <pre>1. Parentheses ()</pre>
# <pre>2. Exponentiation ** </pre>
# <pre>3. Multiplication *, Division /, Floor Division //, Modulus %</pre>
# <pre>4. Addition +, Subtraction -</pre>

# %% [markdown]
# #### **Multiplication, division, floor division, and modulus operations** are evaluated from **left to right**.

# %% [markdown]
# #### **Addition** and **subtraction** operations are evaluated from **left to right**.

# %%
2 + 3 * 4
# Out:
# 14

# %%
(2 + 3) * 4
# Out:
# 20

# %%
2 + 3 * 5 / 5 - 1
# Out:
# 4.0

# %%
2 + 3 * 5 // 5 - 1
# Out:
# 4

# %% [markdown]
# ####  The division / between two integers results in float. The floor division // between two integers results in an integer.

# %%
3 ** 2 ** 2
# Out:
# 81

# %% [markdown]
# #### Exponentiation (**) has right-to-left precedence, meaning the rightmost exponentiation is evaluated first.

# %% [markdown]
# # List, Tuple, Set and Dictionary

# %% [markdown]
# ### List

# %%
listOfElements = [1,2, "Nezuko", 3.5]

# %%
print(listOfElements)
# Out:
# [1, 2, 'Nezuko', 3.5]

# %%
listOfElements[2]
# Out:
# 'Nezuko'

# %%
listOfElements[:3]
# Out:
# [1, 2, 'Nezuko']

# %%
listOfElements[1:3]
# Out:
# [2, 'Nezuko']

# %%
listOfElements[1:]
# Out:
# [2, 'Nezuko', 3.5]

# %% [markdown]
# #### Empty list

# %%
emptyList = []

# %%
emptyList.append([5,'j'])

# %%
emptyList.append(10)

# %%
emptyList
# Out:
# [5, 10, [5, 'j']]

# %%
emptyList = [1] + emptyList

# %%
emptyList
# Out:
# [1, 5, 10, [5, 'j']]

# %% [markdown]
# #### listname.insert(index,object)  inserts a new object in that index position pushing other elements back

# %%
emptyList.insert(0,0.5)

# %%
emptyList
# Out:
# [0.5, 1, 0.5, 0.5, 0.5, 0.5, 5, 10, [5, 'j']]

# %%
emptyList.insert(2,3.5)

# %%
emptyList
# Out:
# [0.5, 1, 3.5, 5, 10]

# %% [markdown]
# ### listname.pop() deletes the last element of that list

# %%
emptyList.pop()
# Out:
# [5, 'j']

# %%
emptyList
# Out:
# [0.5, 1, 0.5, 0.5, 0.5, 0.5, 5, 10]

# %%
emptyList[3] = 5.5

# %% [markdown]
# We can directly change element of any index by simply assigning the value.

# %%
emptyList
# Out:
# [0.5, 1, 0.5, 5.5, 0.5, 0.5, 5, 10]

# %% [markdown]
# #### **List** is **mutable**, meaning you can add, remove, or modify elements after the list is created. Lists are denoted by square brackets **[ ]** and can hold elements of different data types.

# %% [markdown]
# ### Tuple

# %% [markdown]
# #### **Tuples** are **immutable** .

# %%
tuple1 = tuple(emptyList)

# %% [markdown]
# > Creating a tuple out of a list.

# %%
tuple1
# Out:
# (0.5, 1, 0.5, 5.5, 0.5, 0.5, 5, 10)

# %%
tuple2 = (10,20,30,40,50,60)

# %%
tuple2
# Out:
# (10, 20, 30, 40, 50, 60)

# %% [markdown]
# #### Adding elements to tuple

# %%
newTuple = (0,5) + tuple2 + (70, 80)

# %%
newTuple
# Out:
# (0, 5, 10, 20, 30, 40, 50, 60, 70, 80)

# %% [markdown]
# ####**You can concatenate tuples to create a new tuple.**

# %% [markdown]
# #### Removing elements from tuple

# %%
newTuple2 = newTuple[0:3] + newTuple[-3:]

# %%
newTuple2
# Out:
# (0, 5, 10, 60, 70, 80)

# %% [markdown]
# #### Modifying elements in a tuple

# %%
newTuple3 = newTuple2[:2] + (50,) + newTuple2[-2:]

# %% [markdown]
# - In order to add a single value, use (value,) to show that it is a tuple { comma is important }  ex: (50, )
# - No need to use comma at the end it contains more that one element  ex: (50,45)

# %%
newTuple3
# Out:
# (0, 5, 50, 45, 70, 80)

# %% [markdown]
# * Tuple is immutable.

# %%
newTuple3[2] = 50.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 newTuple3[2] = 50.5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Indexing

# %%
newTuple3[2]
# Out:
# 50

# %% [markdown]
# # Slicing

# %%
newTuple3[:3]
# Out:
# (0, 5, 50)

# %% [markdown]
# # Set

# %%
newSet = set(newTuple3)

# %% [markdown]
# ``` Typecasting to set ```

# %%
newSet
# Out:
# {0, 5, 50, 70, 80}

# %%
newSet.add('a')
newSet.add('\n')
newSet.add('A')
newSet.add('?')

# %% [markdown]
# * Set is unordered. So, the output may vary every time you  print a set.

# %%
newSet
# Out:
# {'\n', 0, 5, 50, 70, 80, '?', 'A', 'a'}

# %%
newSet.remove(50)

# %% [markdown]
# - setname.remove(element)         ✔️✔️
# - ~~setname.remove(index)~~       ❌❌

# %%
newSet
# Out:
# {'\n', 0, 5, 70, 80, '?', 'A', 'a'}

# %% [markdown]
# - set.remove() gives KeyError if element is not present in the set.
# - set.discard() doesn't give error if element is not present.

# %%
newSet.discard(70)

# %%
newSet
# Out:
# {'\n', 0, 5, 80, '?', 'A', 'a'}

# %%
updatingSet = {90,3,80,30}
updatingSet
# Out:
# {3, 30, 80, 90}

# %%
type(updatingSet)
# Out:
# set

# %%
updatingSet
# Out:
# {3, 30, 80, 90}

# %%
newSet.update(updatingSet)

# %%
print(newSet)
# Out:
# {0, '\n', 3, 5, 'a', 80, 30, '?', 90, 'A'}

# %%
newSet.update([8,1])

# %%
newSet
# Out:
# {0, 1, 3, 5, 8, 30, 80, 90}

# %% [markdown]
# #### Sets are unordered collections of unique elements.

# %%
newSet[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-0e44643d8de0> in <cell line: 1>()
# ----> 1 newSet[1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# #### Sets do not support indexing or slicing because they are unordered collections.

# %%
newSet2 = {3, 2, 12, 11, 70}

# %%
newSet2
# Out:
# {2, 3, 11, 12, 70}

# %%
sortedSet = sorted(newSet2, reverse=True)
print(sortedSet)
sortedSet = sorted(newSet2, reverse=False)
print(sortedSet)
# Out:
# [70, 12, 11, 3, 2]
# [2, 3, 11, 12, 70]

# %%
newSet3 = {3, 2, 12, 11, 70}
sortedSet2 = sorted(newSet3, reverse=True) # By default reverse = False for sorted().
print(sortedSet2)
# Out:
# [70, 12, 11, 3, 2]

# %% [markdown]
# ### Dictionary

# %%
dictionary1 = {}

dictionary1['Driver'] = 'Sinpachi'
dictionary1['Cook'] = 'Kagura'
dictionary1['Janitor'] = 'Gintama'

dictionary1
# Out:
# {'Driver': 'Sinpachi', 'Cook': 'Kagura', 'Janitor': 'Gintama'}

# %% [markdown]
# dictionary_name[legend] = object

# %%
dictionary2 = {1:'Pen',
               10:'Pencil',
               20:'Notebook',
               3:'Chemistry book',
               4:'Arithmetic book',
               'e':'Eraser',
               'A':1}

# %%
dictionary2
# Out:
# {1: 'Pen',
#  10: 'Pencil',
#  20: 'Notebook',
#  3: 'Chemistry book',
#  4: 'Arithmetic book',
#  'A': 1}

# %%
dictionary2[1]
# Out:
# Pen
# 1

# %%
dictionary2['e']
# Out:
# 'Eraser'

# %%
dictionary2['A']
# Out:
# 1

# %%
dictionary2[3]
# Out:
# 'Chemistry book'

# %%
dictionary2[4]
# Out:
# 'Arithmetic book'

# %% [markdown]
# #### Removing

# %%
del dictionary2['A']

# %%
dictionary2
# Out:
# {1: 'Pen',
#  10: 'Pencil',
#  20: 'Notebook',
#  3: 'Chemistry book',
#  4: 'Arithmetic book',
#  'e': 'Eraser',
#  'A': 1}

# %% [markdown]
# #### **Dictionaries are mutable**, which means their keys and values can be edited after the dictionary is created.

# %%
dictionary2.pop('e')
# Out:
# 'Eraser'

# %%
dictionary2
# Out:
# {1: 'Pen',
#  10: 'Pencil',
#  20: 'Notebook',
#  3: 'Chemistry book',
#  4: 'Arithmetic book',
#  'A': 1}

# %%
dictionary2['e'] = 'Eraser'

# %%
dictionary2
# Out:
# {1: 'Pen',
#  10: 'Pencil',
#  20: 'Notebook',
#  3: 'Chemistry book',
#  4: 'Arithmetic book',
#  'A': 1,
#  'e': 'Eraser'}

# %%
dictionary2[5] = dictionary2.pop('e')

# %% [markdown]
# - pop('key') deletes that key and value from dictionary.
# - popitem() deletes last key and value from dictionary.

# %%
dictionary2.popitem()
# Out:
# (4, 'Arithmetic book')

# %%
dictionary2
# Out:
# {1: 'Pen', 10: 'Pencil', 20: 'Notebook', 3: 'Chemistry book'}

# %%
dictionary2.keys()
# Out:
# dict_keys([1, 10, 20, 3, 4, 5])

# %%
dictionary2.values()
# Out:
# dict_values(['Pen', 'Pencil', 'Notebook', 'Chemistry book', 'Arithmetic book', 'Eraser'])

# %%
dictionary2.items()
# Out:
# dict_items([(1, 'Pen'), (10, 'Pencil'), (20, 'Notebook'), (3, 'Chemistry book'), (4, 'Arithmetic book'), (5, 'Eraser')])

# %% [markdown]
# #### To list

# %%
listOfKeys = list(dictionary2.keys())
listOfKeys
# Out:
# [1, 10, 20, 3, 4, 5]

# %%
tupleOfitems = tuple(dictionary2.items())
tupleOfitems
# Out:
# ((1, 'Pen'),
#  (10, 'Pencil'),
#  (20, 'Notebook'),
#  (3, 'Chemistry book'),
#  (4, 'Arithmetic book'),
#  (5, 'Eraser'))

# %% [markdown]
# #### To string

# %%
dictToString = str(dictionary2)
dictToString
# Out:
# "{1: 'Pen', 10: 'Pencil', 20: 'Notebook', 3: 'Chemistry book', 4: 'Arithmetic book', 5: 'Eraser'}"

# %% [markdown]
# #### From list

# %%
l1 = [['a',1],['b',2],['c',3]]

dictFromList = dict(l1)
dictFromList
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# #### From Tuple

# %%
t1 = (('a',1),('b',2),('c',3))

dictFromList = dict(l1)
dictFromList
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# #### From string

# %%
string1 = "a:1,b:2,c:3"

pairs = string1.split(',')
pairs
# Out:
# ['a:1', 'b:2', 'c:3']

# %%
emptyDict = {}
for pair in pairs:
    key, value = pair.split(':')
    print('The key is :',key)
    print('The value is :',value)
    print('\n')
    emptyDict[key] = int(value)
# Out:
# The key is : a
# The value is : 1
#
#
# The key is : b
# The value is : 2
#
#
# The key is : c
# The value is : 3

# %%
emptyDict
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# # Looping

# %% [markdown]
# ### For Loop

# %%
# for(i = 0; i<=5 ; i++)
# {
#     printf("Welcome everyone.")
# }

# %%
for numbers in range (0,5):
  print(numbers)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for numbers in range (5):
  print(numbers)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ####**range()** generates a sequence a number.

# %%
for numbers in range (0,5,2):
  print(numbers)
# Out:
# 0
# 2
# 4

# %% [markdown]
# #### In Python, a sequence and a list are related but not exactly the same.
#
# #### - **Sequence:** It's a general term used to describe an ordered collection of items where you can access elements by their positions. Sequences can include various types like lists, tuples, strings, etc. They all maintain an order and allow indexing and slicing.
#
# #### - **List:** A list is a specific type of sequence in Python. It's mutable, meaning you can add, remove, or modify elements after the list is created. Lists are denoted by square brackets **[ ]** and can hold elements of different data types.

# %% [markdown]
# #### **range()** returns a sequence called a "**range object.**"

# %% [markdown]
# #### A **range object** represents an immutable sequence of numbers and is designed to generate a **sequence of integers**.
#
# #### It behaves like a sequence that allows iteration over the numbers it represents and supports **indexing** and **slicing**, but it doesn't store all the numbers in memory at once. Instead, it generates them as they are needed, making it memory efficient.

# %% [markdown]
# #### - **Indexing** : Accessing specific elements by their index within the range sequence. ####
#
# #### - **Slicing** : Obtaining a subset of the sequence by specifying start, end, and step size within square brackets. ####

# %% [markdown]
# ### List as a sequence.

# %%
rangeOfNum = range(5,15)
rangeOfNum
# Out:
# range(5, 15)

# %%
rangeOfNum[3]
# Out:
# 8

# %%
rangeOfNum[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 rangeOfNum[10]
#
# IndexError: range object index out of range

# %%
rangeOfNum[0 : 8]
# Out:
# range(5, 13)

# %%
listOfNum = list(rangeOfNum[0 : 8])

listOfNum
# Out:
# [5, 6, 7, 8, 9, 10, 11, 12]

# %%
iterationNum = 1
for elements in listOfNum:
    print(f'Iteration {iterationNum}')
    print(elements)
    iterationNum = iterationNum + 1
    print()
# Out:
# Iteration 1
# 5
#
# Iteration 2
# 6
#
# Iteration 3
# 7
#
# Iteration 4
# 8
#
# Iteration 5
# 9
#
# Iteration 6
# 10
#
# Iteration 7
# 11
#
# Iteration 8
# 12

# %% [markdown]
# ### List of string as a sequence

# %%
listOfString = ['Hattori','Kenechi','Yumeko']
listOfString
# Out:
# ['Hattori', 'Kenechi', 'Yumeko']

# %%
iterationConstant = 1
for elements in listOfString:
    print(f'Iteration {iterationConstant}')
    print(elements)
    iterationConstant = iterationConstant + 1
    print()
# Out:
# Iteration 1
# Hattori
#
# Iteration 2
# Kenechi
#
# Iteration 3
# Yumeko

# %% [markdown]
# ### String as a sequence

# %%
String1= "Hello"

constant = 1
for characters in String1:
    print(f'Iteration {constant}')
    print(characters)
    constant = constant + 1
    print()
# Out:
# Iteration 1
# H
#
# Iteration 2
# e
#
# Iteration 3
# l
#
# Iteration 4
# l
#
# Iteration 5
# o

# %% [markdown]
# ### Dictionary as a sequence

# %%
dictionary1 = {'a': 1, 'b': 2, 'c': 3}
c = 1
for keys,values in dictionary1.items():
    print(f'Iteration {c}')
    print('Key : {} \t Value : {}'.format(keys,values))
    c = c + 1
    print()
# Out:
# Iteration 1
# Key : a 	 Value : 1
#
# Iteration 2
# Key : b 	 Value : 2
#
# Iteration 3
# Key : c 	 Value : 3

# %% [markdown]
# ### While Loop

# %%
count = 0
while count <= 10:
    print(count)
    count += 2
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### Nested Loop

# %%
for i in range(3):    # 0,1,2
    print()
    print('I')
    print(i)

    for j in range(2): # 0,1
        print('J')
        print(j)
# Out:
# I
# 0
# J
# 0
# J
# 1
#
# I
# 1
# J
# 0
# J
# 1
#
# I
# 2
# J
# 0
# J
# 1

# %% [markdown]
# ### Loop control statements ###

# %%
for i in range(5):
    if i == 2:
        continue
    if i == 4:
        break
    print(f'Value of variable i is : {i}')
# Out:
# Value of variable i is : 0
# Value of variable i is : 1
# Value of variable i is : 3

# %% [markdown]
# #### Order of statements can be significant in many cases.

# %%
for i in range(5):
    print(f'Value of variable i is : {i}')
    if i == 2:
        continue
    if i == 4:
        break
# Out:
# Value of variable i is : 0
# Value of variable i is : 1
# Value of variable i is : 2
# Value of variable i is : 3
# Value of variable i is : 4

# %% [markdown]
# ### Simulating do-while

# %%
count = 0

while True:
    print(count)
    count += 1
    if count >= 5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Function

# %%
def circumferenceOfCircle(r):
    circumference = 2 * (22/7) * r
    print ('The circumference of circle is {}.'.format(circumference))

# %%
circumferenceOfCircle(4)
# Out:
# The circumference of circle is 25.142857142857142.

# %%
circumferenceOfCircle(5)
# Out:
# The circumference of circle is 31.428571428571427.

# %%
circumferenceOfCircle(6)
# Out:
# The circumference of circle is 37.714285714285715.
